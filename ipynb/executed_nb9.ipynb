# %%
from os import chdir
chdir('../')
# %matplotlib inline
from lib import *

pd.options.display.precision = 4
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Lato'
mpl.rcParams['font.weight'] = 700
sns.set(font='Lato', font_scale=1)
sns.set()
np.random.seed(42)
suppress_warnings()

# %%
feature = pd.read_pickle('/home/jovyan/work/DSI/projects/project_3/data/feature')
target= pd.read_pickle('/home/jovyan/work/DSI/projects/project_3/data/target')

# %%
display(feature.shape)
display(target.shape)
# Out:
# (11000, 1000)
# (11000, 1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, ShuffleSplit
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_classif
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.decomposition import PCA
from sklearn.linear_model import Lasso, LogisticRegression,LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Step 2 Identify Features

# %%
from sklearn.feature_selection import SelectKBest, \
                                      SelectFromModel, \
                                      RFE, SelectPercentile, \
                                      SelectFdr, SelectFpr
from sklearn.feature_selection import f_regression, f_classif
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Pipeline: Select K best - PCA - SelectFromModel(RFC) - Logistic Regression

# %%
pipe_for_gs = Pipeline([
    ('skb', SelectKBest(score_func=f_classif)),
    ('pca',PCA(random_state=42)),
    ('sfmlr', SelectFromModel(LogisticRegression(C=0.1, penalty='l1',random_state=42))),
    ('sfmrf', SelectFromModel(RandomForestClassifier(random_state=42,n_jobs=-1))),
    ('knc', KNeighborsClassifier())
])

# %%
params = {
    'skb__k':[200,300,500],
    'pca__n_components':[50,100,150],
    'sfmrf__estimator':[  RandomForestClassifier(n_estimators=10, criterion='entropy',random_state=42,n_jobs=-1),
                          RandomForestClassifier(n_estimators=20, criterion='entropy',random_state=42,n_jobs=-1),  
                          RandomForestClassifier(n_estimators=30, criterion='entropy',random_state=42,n_jobs=-1),
                          RandomForestClassifier(n_estimators=40, criterion='entropy',random_state=42,n_jobs=-1),  
                          RandomForestClassifier(n_estimators=50, criterion='entropy',random_state=42,n_jobs=-1),
                        ],                    
}

# %%
gspipe = GridSearchCV(pipe_for_gs,
                      param_grid=params,
                      n_jobs=-1,
                      cv=ShuffleSplit(random_state=42))

# %%
gspipe.fit(feature[:220], np.ravel(target[:220].values))
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=10, random_state=42, test_size=0.1, train_size=None),
#        error_score='raise',
#        estimator=Pipeline(steps=[('skb', SelectKBest(k=10, score_func=<function f_classif at 0x7fe7a1b366a8>)), ('pca', PCA(copy=True, iterated_power='auto', n_components=None, random_state=42,
#   svd_solver='auto', tol=0.0, whiten=False)), ('sfmlr', SelectFromModel(estimator=LogisticRegression(C=0.1, class_weight=None, dual=...owski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'))]),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'pca__n_components': [50, 100, 150], 'skb__k': [200, 300, 500], 'sfmrf__estimator': [RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf...timators=50, n_jobs=-1, oob_score=False, random_state=42,
#             verbose=0, warm_start=False)]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
gspipe.best_score_
# Out:
# 0.55000000000000004

# %%
gspipe.best_estimator_.named_steps
# Out:
# {'knc': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#             metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#             weights='uniform'),
#  'pca': PCA(copy=True, iterated_power='auto', n_components=150, random_state=42,
#    svd_solver='auto', tol=0.0, whiten=False),
#  'sfmlr': SelectFromModel(estimator=LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#            penalty='l1', random_state=42, solver='liblinear', tol=0.0001,
#            verbose=0, warm_start=False),
#          prefit=False, threshold=None),
#  'sfmrf': SelectFromModel(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_split=1e-07, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=10, n_jobs=-1, oob_score=False, random_state=42,
#              verbose=0, warm_start=False),
#          prefit=False, threshold=None),
#  'skb': SelectKBest(k=300, score_func=<function f_classif at 0x7fe7a1b366a8>)}

# %%
gspipe_results = pd.DataFrame(gspipe.cv_results_)
gspipe_results.sort_values('rank_test_score', ascending=True).T
# Out:
#                                                                         31  \
# mean_fit_time                                                      0.04546
# mean_score_time                                                   0.001845
# mean_test_score                                                       0.55
# mean_train_score                                                    0.7333
# param_pca__n_components                                                150
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           300
# params                   {'pca__n_components': 150, 'skb__k': 300, 'sfm...
# rank_test_score                                                          1
# split0_test_score                                                      0.5
# split0_train_score                                                  0.7475
# split1_test_score                                                   0.5455
# split1_train_score                                                  0.6869
# split2_test_score                                                   0.5909
# split2_train_score                                                  0.8384
# split3_test_score                                                   0.6364
# split3_train_score                                                  0.7222
# split4_test_score                                                      0.5
# split4_train_score                                                  0.7525
# split5_test_score                                                   0.6818
# split5_train_score                                                   0.702
# split6_test_score                                                   0.3182
# split6_train_score                                                  0.7576
# split7_test_score                                                   0.6364
# split7_train_score                                                  0.7071
# split8_test_score                                                   0.5909
# split8_train_score                                                  0.7172
# split9_test_score                                                      0.5
# split9_train_score                                                   0.702
# std_fit_time                                                       0.00174
# std_score_time                                                   3.699e-05
# std_test_score                                                     0.09844
# std_train_score                                                     0.0417
#
#                                                                         4   \
# mean_fit_time                                                      0.06023
# mean_score_time                                                   0.002174
# mean_test_score                                                     0.5455
# mean_train_score                                                     0.746
# param_pca__n_components                                                 50
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           300
# params                   {'pca__n_components': 50, 'skb__k': 300, 'sfmr...
# rank_test_score                                                          2
# split0_test_score                                                   0.4545
# split0_train_score                                                  0.7121
# split1_test_score                                                   0.6364
# split1_train_score                                                  0.7222
# split2_test_score                                                   0.5909
# split2_train_score                                                   0.803
# split3_test_score                                                      0.5
# split3_train_score                                                  0.7273
# split4_test_score                                                      0.5
# split4_train_score                                                  0.7323
# split5_test_score                                                   0.5455
# split5_train_score                                                  0.7929
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.7525
# split7_test_score                                                   0.5455
# split7_train_score                                                  0.7475
# split8_test_score                                                   0.5909
# split8_train_score                                                  0.7828
# split9_test_score                                                      0.5
# split9_train_score                                                  0.6869
# std_fit_time                                                      0.004129
# std_score_time                                                   4.431e-05
# std_test_score                                                     0.05378
# std_train_score                                                     0.0355
#
#                                                                         8   \
# mean_fit_time                                                      0.09009
# mean_score_time                                                   0.002811
# mean_test_score                                                     0.5455
# mean_train_score                                                    0.7247
# param_pca__n_components                                                 50
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           500
# params                   {'pca__n_components': 50, 'skb__k': 500, 'sfmr...
# rank_test_score                                                          2
# split0_test_score                                                   0.6818
# split0_train_score                                                  0.7121
# split1_test_score                                                   0.5909
# split1_train_score                                                  0.7374
# split2_test_score                                                   0.6364
# split2_train_score                                                  0.7424
# split3_test_score                                                   0.5909
# split3_train_score                                                  0.7273
# split4_test_score                                                   0.4091
# split4_train_score                                                  0.7273
# split5_test_score                                                   0.5455
# split5_train_score                                                  0.7576
# split6_test_score                                                   0.5909
# split6_train_score                                                   0.702
# split7_test_score                                                   0.3636
# split7_train_score                                                  0.6869
# split8_test_score                                                   0.4545
# split8_train_score                                                   0.697
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7576
# std_fit_time                                                      0.001887
# std_score_time                                                    2.75e-05
# std_test_score                                                     0.09749
# std_train_score                                                     0.0235
#
#                                                                         16  \
# mean_fit_time                                                      0.04426
# mean_score_time                                                   0.001763
# mean_test_score                                                     0.5409
# mean_train_score                                                    0.7328
# param_pca__n_components                                                100
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           300
# params                   {'pca__n_components': 100, 'skb__k': 300, 'sfm...
# rank_test_score                                                          4
# split0_test_score                                                      0.5
# split0_train_score                                                  0.7475
# split1_test_score                                                   0.5455
# split1_train_score                                                  0.6869
# split2_test_score                                                   0.4091
# split2_train_score                                                  0.8232
# split3_test_score                                                   0.6364
# split3_train_score                                                  0.7222
# split4_test_score                                                      0.5
# split4_train_score                                                  0.7525
# split5_test_score                                                   0.6818
# split5_train_score                                                   0.702
# split6_test_score                                                   0.3182
# split6_train_score                                                  0.7576
# split7_test_score                                                   0.6364
# split7_train_score                                                  0.7071
# split8_test_score                                                   0.5909
# split8_train_score                                                  0.7172
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7121
# std_fit_time                                                     0.0008575
# std_score_time                                                   3.804e-05
# std_test_score                                                      0.1065
# std_train_score                                                    0.03728
#
#                                                                         35  \
# mean_fit_time                                                      0.07819
# mean_score_time                                                   0.002782
# mean_test_score                                                     0.5364
# mean_train_score                                                    0.7242
# param_pca__n_components                                                150
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           500
# params                   {'pca__n_components': 150, 'skb__k': 500, 'sfm...
# rank_test_score                                                          5
# split0_test_score                                                   0.4091
# split0_train_score                                                   0.702
# split1_test_score                                                      0.5
# split1_train_score                                                   0.697
# split2_test_score                                                   0.7727
# split2_train_score                                                  0.7222
# split3_test_score                                                   0.5909
# split3_train_score                                                   0.702
# split4_test_score                                                      0.5
# split4_train_score                                                  0.7273
# split5_test_score                                                   0.4091
# split5_train_score                                                  0.7475
# split6_test_score                                                   0.6364
# split6_train_score                                                  0.7323
# split7_test_score                                                   0.4545
# split7_train_score                                                  0.6919
# split8_test_score                                                      0.5
# split8_train_score                                                  0.7626
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7576
# std_fit_time                                                      0.005514
# std_score_time                                                   4.779e-05
# std_test_score                                                      0.1072
# std_train_score                                                    0.02445
#
#                                                                         34  \
# mean_fit_time                                                      0.06105
# mean_score_time                                                   0.002424
# mean_test_score                                                     0.5364
# mean_train_score                                                    0.7419
# param_pca__n_components                                                150
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           300
# params                   {'pca__n_components': 150, 'skb__k': 300, 'sfm...
# rank_test_score                                                          5
# split0_test_score                                                   0.6818
# split0_train_score                                                  0.7879
# split1_test_score                                                      0.5
# split1_train_score                                                  0.7172
# split2_test_score                                                   0.5455
# split2_train_score                                                  0.7576
# split3_test_score                                                   0.3636
# split3_train_score                                                  0.7424
# split4_test_score                                                   0.5909
# split4_train_score                                                  0.7222
# split5_test_score                                                   0.5455
# split5_train_score                                                  0.8333
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.7121
# split7_test_score                                                   0.6364
# split7_train_score                                                  0.6869
# split8_test_score                                                   0.4545
# split8_train_score                                                  0.7576
# split9_test_score                                                   0.4545
# split9_train_score                                                   0.702
# std_fit_time                                                      0.001834
# std_score_time                                                   4.697e-05
# std_test_score                                                     0.09045
# std_train_score                                                     0.0418
#
#                                                                         19  \
# mean_fit_time                                                      0.06095
# mean_score_time                                                   0.002325
# mean_test_score                                                     0.5318
# mean_train_score                                                    0.7636
# param_pca__n_components                                                100
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           300
# params                   {'pca__n_components': 100, 'skb__k': 300, 'sfm...
# rank_test_score                                                          7
# split0_test_score                                                   0.6818
# split0_train_score                                                  0.7879
# split1_test_score                                                      0.5
# split1_train_score                                                  0.7172
# split2_test_score                                                   0.3636
# split2_train_score                                                  0.8939
# split3_test_score                                                   0.3636
# split3_train_score                                                  0.7424
# split4_test_score                                                   0.5909
# split4_train_score                                                  0.7222
# split5_test_score                                                   0.5455
# split5_train_score                                                  0.8333
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.7121
# split7_test_score                                                   0.6364
# split7_train_score                                                  0.6869
# split8_test_score                                                   0.4545
# split8_train_score                                                  0.7576
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7828
# std_fit_time                                                      0.002268
# std_score_time                                                   9.648e-05
# std_test_score                                                      0.1038
# std_train_score                                                    0.05975
#
#                                                                         41  \
# mean_fit_time                                                       0.1161
# mean_score_time                                                   0.003706
# mean_test_score                                                     0.5318
# mean_train_score                                                    0.7172
# param_pca__n_components                                                150
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           500
# params                   {'pca__n_components': 150, 'skb__k': 500, 'sfm...
# rank_test_score                                                          7
# split0_test_score                                                   0.4545
# split0_train_score                                                  0.7374
# split1_test_score                                                   0.6818
# split1_train_score                                                  0.7071
# split2_test_score                                                   0.5455
# split2_train_score                                                  0.7222
# split3_test_score                                                      0.5
# split3_train_score                                                   0.697
# split4_test_score                                                   0.4545
# split4_train_score                                                  0.6919
# split5_test_score                                                      0.5
# split5_train_score                                                  0.7222
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.7374
# split7_test_score                                                      0.5
# split7_train_score                                                  0.7222
# split8_test_score                                                   0.5909
# split8_train_score                                                  0.7374
# split9_test_score                                                      0.5
# split9_train_score                                                   0.697
# std_fit_time                                                      0.005296
# std_score_time                                                   9.398e-05
# std_test_score                                                     0.06757
# std_train_score                                                     0.0169
#
#                                                                         0   \
# mean_fit_time                                                      0.03871
# mean_score_time                                                   0.001678
# mean_test_score                                                     0.5273
# mean_train_score                                                    0.7662
# param_pca__n_components                                                 50
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           200
# params                   {'pca__n_components': 50, 'skb__k': 200, 'sfmr...
# rank_test_score                                                          9
# split0_test_score                                                   0.4545
# split0_train_score                                                  0.7778
# split1_test_score                                                   0.5455
# split1_train_score                                                  0.8131
# split2_test_score                                                      0.5
# split2_train_score                                                  0.8636
# split3_test_score                                                   0.3636
# split3_train_score                                                  0.7626
# split4_test_score                                                   0.7273
# split4_train_score                                                   0.702
# split5_test_score                                                   0.5909
# split5_train_score                                                  0.7323
# split6_test_score                                                   0.5455
# split6_train_score                                                  0.7222
# split7_test_score                                                      0.5
# split7_train_score                                                  0.7475
# split8_test_score                                                   0.4545
# split8_train_score                                                  0.8182
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7222
# std_fit_time                                                     0.0008583
# std_score_time                                                   6.927e-05
# std_test_score                                                      0.0936
# std_train_score                                                    0.04902
#
#                                                                         26  \
# mean_fit_time                                                       0.1176
# mean_score_time                                                    0.00369
# mean_test_score                                                     0.5227
# mean_train_score                                                    0.7061
# param_pca__n_components                                                100
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           500
# params                   {'pca__n_components': 100, 'skb__k': 500, 'sfm...
# rank_test_score                                                         10
# split0_test_score                                                   0.4091
# split0_train_score                                                  0.7121
# split1_test_score                                                      0.5
# split1_train_score                                                  0.7172
# split2_test_score                                                   0.6818
# split2_train_score                                                  0.6667
# split3_test_score                                                   0.6818
# split3_train_score                                                  0.6919
# split4_test_score                                                   0.3636
# split4_train_score                                                  0.7273
# split5_test_score                                                   0.5455
# split5_train_score                                                  0.7222
# split6_test_score                                                   0.6364
# split6_train_score                                                  0.6869
# split7_test_score                                                   0.3636
# split7_train_score                                                  0.6869
# split8_test_score                                                   0.5455
# split8_train_score                                                  0.7121
# split9_test_score                                                      0.5
# split9_train_score                                                  0.7374
# std_fit_time                                                      0.009363
# std_score_time                                                   0.0003101
# std_test_score                                                      0.1136
# std_train_score                                                    0.02092
#
#                                                ...                          \
# mean_fit_time                                  ...
# mean_score_time                                ...
# mean_test_score                                ...
# mean_train_score                               ...
# param_pca__n_components                        ...
# param_sfmrf__estimator                         ...
# param_skb__k                                   ...
# params                                         ...
# rank_test_score                                ...
# split0_test_score                              ...
# split0_train_score                             ...
# split1_test_score                              ...
# split1_train_score                             ...
# split2_test_score                              ...
# split2_train_score                             ...
# split3_test_score                              ...
# split3_train_score                             ...
# split4_test_score                              ...
# split4_train_score                             ...
# split5_test_score                              ...
# split5_train_score                             ...
# split6_test_score                              ...
# split6_train_score                             ...
# split7_test_score                              ...
# split7_train_score                             ...
# split8_test_score                              ...
# split8_train_score                             ...
# split9_test_score                              ...
# split9_train_score                             ...
# std_fit_time                                   ...
# std_score_time                                 ...
# std_test_score                                 ...
# std_train_score                                ...
#
#                                                                         9   \
# mean_fit_time                                                      0.08457
# mean_score_time                                                    0.00315
# mean_test_score                                                     0.4682
# mean_train_score                                                    0.8091
# param_pca__n_components                                                 50
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           200
# params                   {'pca__n_components': 50, 'skb__k': 200, 'sfmr...
# rank_test_score                                                         36
# split0_test_score                                                   0.3636
# split0_train_score                                                  0.8535
# split1_test_score                                                   0.6818
# split1_train_score                                                  0.7626
# split2_test_score                                                   0.5909
# split2_train_score                                                  0.8182
# split3_test_score                                                   0.4545
# split3_train_score                                                  0.7525
# split4_test_score                                                      0.5
# split4_train_score                                                  0.8081
# split5_test_score                                                   0.3636
# split5_train_score                                                  0.8283
# split6_test_score                                                   0.3636
# split6_train_score                                                  0.7929
# split7_test_score                                                   0.2727
# split7_train_score                                                  0.8535
# split8_test_score                                                      0.5
# split8_train_score                                                  0.8434
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7778
# std_fit_time                                                      0.002427
# std_score_time                                                   4.104e-05
# std_test_score                                                      0.1221
# std_train_score                                                     0.0349
#
#                                                                         44  \
# mean_fit_time                                                       0.1329
# mean_score_time                                                   0.004394
# mean_test_score                                                     0.4636
# mean_train_score                                                    0.7071
# param_pca__n_components                                                150
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           500
# params                   {'pca__n_components': 150, 'skb__k': 500, 'sfm...
# rank_test_score                                                         37
# split0_test_score                                                      0.5
# split0_train_score                                                  0.7222
# split1_test_score                                                      0.5
# split1_train_score                                                  0.6667
# split2_test_score                                                   0.5455
# split2_train_score                                                  0.6919
# split3_test_score                                                   0.4545
# split3_train_score                                                  0.6869
# split4_test_score                                                   0.3636
# split4_train_score                                                  0.7121
# split5_test_score                                                   0.4091
# split5_train_score                                                  0.7071
# split6_test_score                                                   0.5455
# split6_train_score                                                  0.7071
# split7_test_score                                                   0.2727
# split7_train_score                                                  0.7121
# split8_test_score                                                   0.5455
# split8_train_score                                                  0.7424
# split9_test_score                                                      0.5
# split9_train_score                                                  0.7222
# std_fit_time                                                      0.003087
# std_score_time                                                   0.0002852
# std_test_score                                                     0.08576
# std_train_score                                                    0.02008
#
#                                                                         6   \
# mean_fit_time                                                      0.07033
# mean_score_time                                                   0.002667
# mean_test_score                                                     0.4636
# mean_train_score                                                    0.7919
# param_pca__n_components                                                 50
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           200
# params                   {'pca__n_components': 50, 'skb__k': 200, 'sfmr...
# rank_test_score                                                         37
# split0_test_score                                                   0.3636
# split0_train_score                                                  0.8535
# split1_test_score                                                   0.6818
# split1_train_score                                                  0.7576
# split2_test_score                                                   0.4091
# split2_train_score                                                  0.7273
# split3_test_score                                                   0.4545
# split3_train_score                                                  0.7424
# split4_test_score                                                      0.5
# split4_train_score                                                  0.8485
# split5_test_score                                                      0.5
# split5_train_score                                                  0.7222
# split6_test_score                                                   0.3636
# split6_train_score                                                  0.7929
# split7_test_score                                                   0.2727
# split7_train_score                                                  0.8535
# split8_test_score                                                      0.5
# split8_train_score                                                  0.8434
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7778
# std_fit_time                                                      0.002925
# std_score_time                                                   7.164e-05
# std_test_score                                                      0.1128
# std_train_score                                                     0.0513
#
#                                                                         3   \
# mean_fit_time                                                      0.06099
# mean_score_time                                                   0.002299
# mean_test_score                                                     0.4636
# mean_train_score                                                    0.7894
# param_pca__n_components                                                 50
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           200
# params                   {'pca__n_components': 50, 'skb__k': 200, 'sfmr...
# rank_test_score                                                         37
# split0_test_score                                                      0.5
# split0_train_score                                                  0.8535
# split1_test_score                                                   0.5909
# split1_train_score                                                  0.8182
# split2_test_score                                                   0.4091
# split2_train_score                                                  0.7273
# split3_test_score                                                   0.4545
# split3_train_score                                                  0.7374
# split4_test_score                                                   0.7273
# split4_train_score                                                  0.6818
# split5_test_score                                                   0.3636
# split5_train_score                                                  0.8283
# split6_test_score                                                   0.3636
# split6_train_score                                                  0.7929
# split7_test_score                                                   0.2727
# split7_train_score                                                  0.8283
# split8_test_score                                                   0.3636
# split8_train_score                                                  0.8485
# split9_test_score                                                   0.5909
# split9_train_score                                                  0.7778
# std_fit_time                                                      0.008103
# std_score_time                                                   0.0002265
# std_test_score                                                      0.1314
# std_train_score                                                    0.05454
#
#                                                                         20  \
# mean_fit_time                                                      0.07619
# mean_score_time                                                   0.002631
# mean_test_score                                                     0.4591
# mean_train_score                                                    0.7091
# param_pca__n_components                                                100
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           500
# params                   {'pca__n_components': 100, 'skb__k': 500, 'sfm...
# rank_test_score                                                         40
# split0_test_score                                                   0.4091
# split0_train_score                                                  0.6667
# split1_test_score                                                   0.5455
# split1_train_score                                                   0.702
# split2_test_score                                                      0.5
# split2_train_score                                                  0.7374
# split3_test_score                                                   0.5455
# split3_train_score                                                  0.6818
# split4_test_score                                                   0.4091
# split4_train_score                                                  0.6667
# split5_test_score                                                   0.4545
# split5_train_score                                                  0.7172
# split6_test_score                                                   0.4091
# split6_train_score                                                  0.7424
# split7_test_score                                                   0.4091
# split7_train_score                                                  0.7071
# split8_test_score                                                   0.5455
# split8_train_score                                                  0.7626
# split9_test_score                                                   0.3636
# split9_train_score                                                  0.7071
# std_fit_time                                                      0.003484
# std_score_time                                                   0.0003587
# std_test_score                                                     0.06571
# std_train_score                                                     0.0304
#
#                                                                         22  \
# mean_fit_time                                                      0.07869
# mean_score_time                                                   0.003031
# mean_test_score                                                     0.4591
# mean_train_score                                                    0.7813
# param_pca__n_components                                                100
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           300
# params                   {'pca__n_components': 100, 'skb__k': 300, 'sfm...
# rank_test_score                                                         40
# split0_test_score                                                   0.4545
# split0_train_score                                                  0.8232
# split1_test_score                                                      0.5
# split1_train_score                                                  0.7222
# split2_test_score                                                   0.3182
# split2_train_score                                                  0.8232
# split3_test_score                                                   0.4545
# split3_train_score                                                  0.7121
# split4_test_score                                                   0.3182
# split4_train_score                                                  0.7273
# split5_test_score                                                   0.5455
# split5_train_score                                                  0.8283
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.7929
# split7_test_score                                                   0.4091
# split7_train_score                                                  0.7475
# split8_test_score                                                   0.4545
# split8_train_score                                                  0.8485
# split9_test_score                                                   0.5455
# split9_train_score                                                  0.7879
# std_fit_time                                                      0.003122
# std_score_time                                                   0.0004423
# std_test_score                                                     0.08732
# std_train_score                                                     0.0477
#
#                                                                         17  \
# mean_fit_time                                                       0.0567
# mean_score_time                                                   0.002021
# mean_test_score                                                     0.4545
# mean_train_score                                                    0.7217
# param_pca__n_components                                                100
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           500
# params                   {'pca__n_components': 100, 'skb__k': 500, 'sfm...
# rank_test_score                                                         42
# split0_test_score                                                   0.4091
# split0_train_score                                                  0.7273
# split1_test_score                                                   0.5455
# split1_train_score                                                   0.697
# split2_test_score                                                   0.4091
# split2_train_score                                                  0.6919
# split3_test_score                                                   0.5455
# split3_train_score                                                  0.7071
# split4_test_score                                                   0.5455
# split4_train_score                                                  0.7323
# split5_test_score                                                   0.4091
# split5_train_score                                                  0.7626
# split6_test_score                                                   0.4545
# split6_train_score                                                  0.6919
# split7_test_score                                                   0.3182
# split7_train_score                                                  0.7323
# split8_test_score                                                   0.4091
# split8_train_score                                                  0.7424
# split9_test_score                                                      0.5
# split9_train_score                                                  0.7323
# std_fit_time                                                      0.002234
# std_score_time                                                   8.079e-05
# std_test_score                                                     0.07329
# std_train_score                                                    0.02252
#
#                                                                         37  \
# mean_fit_time                                                      0.07875
# mean_score_time                                                   0.003009
# mean_test_score                                                       0.45
# mean_train_score                                                    0.7869
# param_pca__n_components                                                150
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           300
# params                   {'pca__n_components': 150, 'skb__k': 300, 'sfm...
# rank_test_score                                                         43
# split0_test_score                                                   0.4545
# split0_train_score                                                  0.8232
# split1_test_score                                                      0.5
# split1_train_score                                                  0.7222
# split2_test_score                                                   0.3636
# split2_train_score                                                  0.8889
# split3_test_score                                                   0.4545
# split3_train_score                                                  0.7121
# split4_test_score                                                   0.3182
# split4_train_score                                                  0.7273
# split5_test_score                                                   0.5455
# split5_train_score                                                  0.8283
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.7929
# split7_test_score                                                   0.4091
# split7_train_score                                                  0.7475
# split8_test_score                                                   0.4545
# split8_train_score                                                  0.8485
# split9_test_score                                                   0.4091
# split9_train_score                                                  0.7778
# std_fit_time                                                      0.003095
# std_score_time                                                   0.0003074
# std_test_score                                                     0.07727
# std_train_score                                                    0.05677
#
#                                                                         18  \
# mean_fit_time                                                      0.05434
# mean_score_time                                                   0.002213
# mean_test_score                                                     0.4409
# mean_train_score                                                    0.7919
# param_pca__n_components                                                100
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           200
# params                   {'pca__n_components': 100, 'skb__k': 200, 'sfm...
# rank_test_score                                                         44
# split0_test_score                                                   0.4545
# split0_train_score                                                  0.7879
# split1_test_score                                                   0.4545
# split1_train_score                                                  0.7475
# split2_test_score                                                   0.4545
# split2_train_score                                                  0.7172
# split3_test_score                                                   0.4091
# split3_train_score                                                  0.7475
# split4_test_score                                                   0.4545
# split4_train_score                                                  0.8687
# split5_test_score                                                   0.3636
# split5_train_score                                                  0.8283
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.6869
# split7_test_score                                                   0.3182
# split7_train_score                                                  0.8283
# split8_test_score                                                      0.5
# split8_train_score                                                  0.8333
# split9_test_score                                                   0.4091
# split9_train_score                                                  0.8737
# std_fit_time                                                      0.001528
# std_score_time                                                   6.238e-05
# std_test_score                                                     0.07056
# std_train_score                                                    0.06127
#
#                                                                         33
# mean_fit_time                                                      0.05436
# mean_score_time                                                   0.002275
# mean_test_score                                                     0.4409
# mean_train_score                                                    0.7798
# param_pca__n_components                                                150
# param_sfmrf__estimator                                                  ()
# param_skb__k                                                           200
# params                   {'pca__n_components': 150, 'skb__k': 200, 'sfm...
# rank_test_score                                                         44
# split0_test_score                                                   0.4545
# split0_train_score                                                  0.7879
# split1_test_score                                                   0.4545
# split1_train_score                                                  0.7475
# split2_test_score                                                   0.4545
# split2_train_score                                                  0.7172
# split3_test_score                                                   0.4091
# split3_train_score                                                  0.7475
# split4_test_score                                                   0.4545
# split4_train_score                                                  0.7475
# split5_test_score                                                   0.3636
# split5_train_score                                                  0.8283
# split6_test_score                                                   0.5909
# split6_train_score                                                  0.6869
# split7_test_score                                                   0.3182
# split7_train_score                                                  0.8283
# split8_test_score                                                      0.5
# split8_train_score                                                  0.8333
# split9_test_score                                                   0.4091
# split9_train_score                                                  0.8737
# std_fit_time                                                      0.001167
# std_score_time                                                   5.523e-05
# std_test_score                                                     0.07056
# std_train_score                                                     0.0567
#
# [33 rows x 45 columns]

# %%
gspipe_results['mean_fit_time'].sum()
# Out:
# 3.6572552442550661

# %%
gspipe_results.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 33 columns):
# mean_fit_time              45 non-null float64
# mean_score_time            45 non-null float64
# mean_test_score            45 non-null float64
# mean_train_score           45 non-null float64
# param_pca__n_components    45 non-null object
# param_sfmrf__estimator     45 non-null object
# param_skb__k               45 non-null object
# params                     45 non-null object
# rank_test_score            45 non-null int32
# split0_test_score          45 non-null float64
# split0_train_score         45 non-null float64
# split1_test_score          45 non-null float64
# split1_train_score         45 non-null float64
# split2_test_score          45 non-null float64
# split2_train_score         45 non-null float64
# split3_test_score          45 non-null float64
# split3_train_score         45 non-null float64
# split4_test_score          45 non-null float64
# split4_train_score         45 non-null float64
# split5_test_score          45 non-null float64
# split5_train_score         45 non-null float64
# split6_test_score          45 non-null float64
# split6_train_score         45 non-null float64
# split7_test_score          45 non-null float64
# split7_train_score         45 non-null float64
# split8_test_score          45 non-null float64
# split8_train_score         45 non-null float64
# split9_test_score          45 non-null float64
# split9_train_score         45 non-null float64
# std_fit_time               45 non-null float64
# std_score_time             45 non-null float64
# std_test_score             45 non-null float64
# std_train_score            45 non-null float64
# dtypes: float64(28), int32(1), object(4)
# memory usage: 27.0 KB

# %%
print("Fit time .1% data: ", gspipe_results['mean_fit_time'].sum())
print("Best Score .1% data: ",gspipe.best_score_)
### Pipeline3 for .1% (220 rows)
picked_pipeline_220row = \
        pd.DataFrame.to_pickle(gspipe_results,\
        '/home/jovyan/work/DSI/projects/project_3/data/Pipeline3_knc_pt1_percent')
# Out:
# Fit time .1% data:  3.65725524426
# Best Score .1% data:  0.55

# %%
### Pipeline3 for .5% (1100 rows)

gspipe.fit(feature[:1100], np.ravel(target[:1100].values))
gspipe_results = pd.DataFrame(gspipe.cv_results_)
print("Fit time .5% data: ", gspipe_results['mean_fit_time'].sum())
print("Best Score .5% data: ",gspipe.best_score_)
gspipe_results_1100 = pd.DataFrame(gspipe.cv_results_)
picked_Pipeline3_1100row = \
        pd.DataFrame.to_pickle(gspipe_results_1100,\
        '/home/jovyan/work/DSI/projects/project_3/data/Pipeline3_knc_pt5_percent')
# Out:
# Fit time .5% data:  20.1695360661
# Best Score .5% data:  0.524545454545

# %%
### Pipeline3 for 1% (2200 rows)

gspipe.fit(feature[:2200], np.ravel(target[:2200].values))
gspipe_results = pd.DataFrame(gspipe.cv_results_)
print("Fit time 1% data: ", gspipe_results['mean_fit_time'].sum())
print("Best Score 1% data: ",gspipe.best_score_)
gspipe_results_2200 = pd.DataFrame(gspipe.cv_results_)
picked_Pipeline2_2200row = \
        pd.DataFrame.to_pickle(gspipe_results_2200,\
        '/home/jovyan/work/DSI/projects/project_3/data/Pipeline3_knc_1_percent')
# Out:
# Fit time 1% data:  46.4679171562
# Best Score 1% data:  0.534545454545

# %%
### Bench Marking for 5% (11000 rows)

gspipe.fit(feature, np.ravel(target.values))
gspipe_results = pd.DataFrame(gspipe.cv_results_)
print("Fit time 1% data: ", gspipe_results['mean_fit_time'].sum())
print("Best Score 1% data:",gspipe.best_score_)
gspipe_results11000 = pd.DataFrame(gspipe.cv_results_)
picked_GS_BenchMarkig_11000row = \
        pd.DataFrame.to_pickle(gspipe_results_2200,\
        '/home/jovyan/work/DSI/projects/project_3/data/Pipeline3_knc_5_percent')
# Out:
# Fit time 1% data:  324.115505028
# Best Score 1% data: 0.525909090909
